# %%
import matplotlib.pyplot as plt
import pandas as pd
from wordcloud import WordCloud

# %% [markdown]
# # Exploring the data
# Goal: To create an exemplary heatmap description for each bird species.
# ## Loading the data

# %%
dt = pd.read_csv('cleaned_simulatedusers.csv')
dt.head(3)
# Out:
#    Unnamed: 0            StartDate              EndDate  Status  Progress  \
# 0           1  2023-08-01 14:01:37  2023-08-01 14:01:36       0       100
# 1           2  2023-08-01 14:01:37  2023-08-01 14:01:36       0       100
# 2           3  2023-08-01 14:02:01  2023-08-01 14:02:01       0       100
#
#    Duration..in.seconds.  Finished         RecordedDate         ResponseId  \
# 0                   1109         1  2023-08-01 14:01:37  R_1gkfzBPvI9tDhOO
# 1                    782         1  2023-08-01 14:01:37  R_1r3qOxSCHmcy2lD
# 2                    758         1  2023-08-01 14:02:01  R_3nNk586iod3ei9K
#
#   DistributionChannel  ... Q_2.1  Q_3.1 Q_8.1  Q_5.1 Q_6.1  \
# 0           anonymous  ...     2      2     7      3     1
# 1           anonymous  ...     4      3     4      5     4
# 2           anonymous  ...     5      5     4      2     2
#
#                                               Q2.1.1  Q2.2  \
# 0  In the first case it was very helpful, heatmap...   NaN
# ...

# %% [markdown]
# ## Exploring bird descritpions of single users

# %%
dt['Q10'].iloc[44]
# Out:
# 'Parakeet Auklet'

# %%
dt[['Warmup_2_RA', 'Warmup_2_LA', 'Warmup_2_PA', 'Warmup_2_CA']].iloc[44]
# Out:
# Warmup_2_RA    Heat mainly on the head , particularly around ...
# Warmup_2_LA                                 Mainly on the belly.
# Warmup_2_PA                      Heat on the belly and the head.
# Warmup_2_CA                          Heat around the whole head.
# Name: 44, dtype: object

# %% [markdown]
# ## Exploring descriptions of all users
# These word clouds were used to create an exemplary heatmap description for every bird species.

# %%
wordcloud = WordCloud().generate(' '.join(dt['Warmup_2_RA']))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wordcloud = WordCloud().generate(' '.join(dt['Warmup_2_LA']))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wordcloud = WordCloud().generate(' '.join(dt['Warmup_2_PA']))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wordcloud = WordCloud().generate(' '.join(dt['Warmup_2_CA']))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
